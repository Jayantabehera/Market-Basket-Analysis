# %% [markdown]
# # Implementing FP Growth using Spark Dataframe

# %% [markdown]
# Importing Libraries

# %%
##Importing Libraries
import re
import warnings
import pandas as pd
import json
import numpy as np
import pyfpgrowth
import pyspark
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import udf
import pyspark.sql.functions as func
from pyspark.sql.types import ArrayType, StringType
from pyspark.ml.fpm import FPGrowth
#import spark
import time

# %% [markdown]
# Create Spark Session

# %%
sc = SparkContext.getOrCreate()
spark1 = SparkSession(sc)

# %% [markdown]
# Load Dataset

# %%
df = spark1.read.csv("BigTempRb.txt", sep=',',header='true', inferSchema='true',escape="\"" )
#df.dtypes

# %% [markdown]
# Select columns and check row count

# %%
df = df.select("RequestTimestamp","ResponseRgBasketId","RequestSiteId",
      "RequestBasketValue","RequestBasketId",
      "RequestNumberBasketItems","RequestBasketJsonString")
#df.show()
df.count()
# Out:
# 10020

# %% [markdown]
# Create ItemList column

# %%
### UDF to extract item list from json
def get_item_list(item_json):
    #print(item_json)
    response = json.loads(item_json)
    lister = []
    for nest in response['items']:
        lister.append(nest["b"])
    return (list(set(lister)))

### converting above function to a UDF
item_list = udf(get_item_list, ArrayType(StringType()))

## Creating item_list from JsonString
df = df.withColumn('ItemList', item_list(df.RequestBasketJsonString))

# %%
df.show(10) ## Display first 10 entries of PySpark Dataframe
# Out:
# +--------------------+--------------------+-------------+------------------+---------------+------------------------+-----------------------+--------------------+
# |    RequestTimestamp|  ResponseRgBasketId|RequestSiteId|RequestBasketValue|RequestBasketId|RequestNumberBasketItems|RequestBasketJsonString|            ItemList|
# +--------------------+--------------------+-------------+------------------+---------------+------------------------+-----------------------+--------------------+
# |2018-11-27 14:13:...|cf31c58d05ca41bda...|         7333|              14.6|    73335271658|                       5|   {"id":"7333527165...|[5000128725477, 5...|
# |2018-11-27 16:35:...|1d385ce056e1463a8...|         5775|              2.54|   577522888398|                       3|   {"id":"5775228883...|[5010891011868, 8...|
# |2018-11-27 22:34:...|b9083214cf6c4593b...|         7392|              6.35|     7392753009|                       4|   {"id":"7392753009...|[5000128797436, 5...|
# |2018-11-27 11:52:...|7da158b1c1d14fdf8...|         8487|             18.63|    84873530474|                       9|   {"id":"8487353047...|[4062300011847, 5...|
# |2018-11-27 14:20:...|ce2c0ef55f4c47d1b...|         7868|             42.99|   786812414557|                       4|   {"id":"7868124145...|[6191514300312, 5...|
# |2018-11-27 08:22:...|23af5a43bb3043b3a...|         6952|              1.29|    69523898222|                       2|   {"id":"6952389822...|[9770307268922, 5...|
# |2018-11-27 14:42:...|e9e24506d4c64b5ba...|         8049|               2.0|    80495233085|                       1|   {"id":"8049523308...|     [7622210286314]|
# |2018-11-27 13:23:...|43a4bfda05d44538b...|         9808|               4.5|   980871386917|                       3|   {"id":"9808713869...|[5000128677127, 7...|
# |2018-11-27 17:00:...|6ce95a109c024ce9a...|         5160|               1.5|    51606159402|                       1|   {"id":"5160615940...|     [0000050457243]|
# |2018-11-27 10:31:...|cebc44a6e43d4c9f9...|         8247|              8.35|   824721660517|                       1|   {"id":"8247216605...|     [5000431027169]|
# +--------------------+--------------------+-------------+------------------+---------------+------------------------+-----------------------+--------------------+
# only showing top 10 rows

# %%
len(df.rdd.map(lambda x: x.ItemList).collect())
# Out:
# 10020

# %% [markdown]
# Build FPGrwoth

# %%
## input paramters
input_support = .0002 ## VALUE RANGES BETWEEN 0 AND 1
input_confidence = 0.001 ## VALUE RANGES BETWEEN 0 AND 1

############### Applying Pyspark FPgrowth algorithm ######################
start = time.time()
fpGrowth = FPGrowth(itemsCol="ItemList", minSupport=input_support, minConfidence=input_confidence)
model = fpGrowth.fit(df)
model_time = time.time() - start

# %%
model_time
# Out:
# 2.3794689178466797

# %%
# Display frequent itemsets.
model.freqItemsets.show()
model.freqItemsets.count()
# Out:
# +--------------------+----+
# |               items|freq|
# +--------------------+----+
# |     [5000128701730]|   3|
# |     [0000050939886]|   3|
# |     [3046920029759]|   4|
# |     [0000050248346]|   4|
# |     [5010043000016]|  15|
# |     [5010455063142]|  34|
# |[5010455063142, 7...|   3|
# |[5010455063142, 5...|   3|
# |     [5000128769433]|  10|
# |     [5054267000704]|  28|
# |[5054267000704, 5...|   3|
# |     [5000128610070]|  14|
# |     [5000128651691]|   5|
# |     [5012035955892]|   3|
# |     [5000128193610]|  11|
# |     [5000128711449]|  42|
# |[5000128711449, 5...|   4|
# |[5000128711449, 0...|   3|
# |     [5010394986076]|   6|
# |     [5000128867849]|  10|
# +--------------------+----+
# only showing top 20 rows
# 4837

# %%
# Generating association rules.
rules = model.associationRules
rules = rules.withColumn("confidence", func.round(rules["confidence"], 4)) ## Rounding values to 4 decimals for confidence
rules = rules.withColumn("lift", func.round(rules["lift"], 2)) ## Rounding values to 2 decimal for lift
rules.show()
rules.count()
# Out:
# +---------------+---------------+----------+-------+
# |     antecedent|     consequent|confidence|   lift|
# +---------------+---------------+----------+-------+
# |[5000128597685]|[5000128597623]|    0.3333|  133.6|
# |[5000128833813]|[5000128664288]|     0.125|  78.28|
# |[5000128833813]|[5000128655996]|     0.125|  32.96|
# |[5000128833813]|[5000128785617]|     0.125|   2.39|
# |[5000128833813]|[0000000000145]|     0.125|   1.77|
# |[5000328806181]|[0000000000145]|    0.3333|   4.72|
# |[5000128766708]|[5000128766586]|    0.0625|  18.98|
# |[5000128766708]|[5000128072915]|    0.0469|   7.96|
# |[5000128766708]|[5000128785617]|    0.0625|   1.19|
# |[5000128766708]|[0000000007535]|    0.0469|   2.21|
# |[5000128766708]|[5010092093441]|    0.0469|  13.05|
# |[0000096135846]|[6191514300312]|       0.2|   8.38|
# |[5023528000036]|[0000000000145]|    0.3333|   4.72|
# |[5000128979726]|[0000000000145]|    0.2308|   3.27|
# |[5000128889889]|[5010228013213]|    0.3333| 556.67|
# |[5000128889889]|[5000205039862]|    0.3333|1113.33|
# |[5000128889889]|[5000128785617]|    0.3333|   6.36|
# |[5000128889889]|[8712566328352]|    0.3333| 556.67|
# |[5000128889889]|[5000205034546]|    0.3333|  668.0|
# |[5060043260491]|[5000128540155]|    0.2105|  68.05|
# +---------------+---------------+----------+-------+
# only showing top 20 rows
# 3661

# %%
#rules.collect() ## Checking the entire generated rules.  Do not execute this code if the data is big, so commenting out.
# Out:
# [Row(antecedent=['5000128597685'], consequent=['5000128597623'], confidence=0.3333, lift=133.6),
#  Row(antecedent=['5000128833813'], consequent=['5000128664288'], confidence=0.125, lift=78.28),
#  Row(antecedent=['5000128833813'], consequent=['5000128655996'], confidence=0.125, lift=32.96),
#  Row(antecedent=['5000128833813'], consequent=['5000128785617'], confidence=0.125, lift=2.39),
#  Row(antecedent=['5000128833813'], consequent=['0000000000145'], confidence=0.125, lift=1.77),
#  Row(antecedent=['5000328806181'], consequent=['0000000000145'], confidence=0.3333, lift=4.72),
#  Row(antecedent=['5000128766708'], consequent=['5000128766586'], confidence=0.0625, lift=18.98),
#  Row(antecedent=['5000128766708'], consequent=['5000128072915'], confidence=0.0469, lift=7.96),
#  Row(antecedent=['5000128766708'], consequent=['5000128785617'], confidence=0.0625, lift=1.19),
#  Row(antecedent=['5000128766708'], consequent=['0000000007535'], confidence=0.0469, lift=2.21),
#  Row(antecedent=['5000128766708'], consequent=['5010092093441'], confidence=0.0469, lift=13.05),
#  Row(antecedent=['0000096135846'], consequent=['6191514300312'], confidence=0.2, lift=8.38),
#  Row(antecedent=['5023528000036'], consequent=['0000000000145'], confidence=0.3333, lift=4.72),
#  Row(antecedent=['5000128979726'], consequent=['0000000000145'], confidence=0.2308, lift=3.27),
#  Row(antecedent=['5000128889889'], consequent=['5010228013213'], confidence=0.3333, lift=556.67),
#  Row(antecedent=['5000128889889'], consequent=['5000205039862'], confidence=0.3333, lift=1113.33),
#  Row(antecedent=['5000128889889'], consequent=['5000128785617'], confidence=0.3333, lift=6.36),
#  Row(antecedent=['5000128889889'], consequent=['8712566328352'], confidence=0.3333, lift=556.67),
#  Row(antecedent=['5000128889889'], consequent=['5000205034546'], confidence=0.3333, lift=668.0),
#  Row(antecedent=['5060043260491'], consequent=['5000128540155'], confidence=0.2105, lift=68.05),
#  Row(antecedent=['5060043260491'], consequent=['0000050128747'], confidence=0.1579, lift=56.5),
#  Row(antecedent=['5060043260491'], consequent=['0000000000145'], confidence=0.1579, lift=2.23),
#  Row(antecedent=['5000128663250', '0000000000145'], consequent=['5000128661911'], confidence=0.75, lift=289.04),
#  Row(antecedent=['5000128982917'], consequent=['5000128785617'], confidence=0.15, lift=2.86),
#  Row(antecedent=['2083801000002', '2083803000000'], consequent=['6100000000193'], confidence=0.0833, lift=7.32),
#  Row(antecedent=['2083801000002', '2083803000000'], consequent=['9770307268922'], confidence=0.0833, lift=3.61),
#  Row(antecedent=['2083801000002', '2083803000000'], consequent=['5000128104524'], confidence=0.0833, lift=2.97),
#  Row(antecedent=['5000128721318'], consequent=['5000128663076'], confidence=1.0, lift=345.52),
#  Row(antecedent=['5000128721318'], consequent=['5000128663250'], confidence=0.75, lift=278.33),
#  Row(antecedent=['7622210891747'], consequent=['0000000000644'], confidence=0.2667, lift=12.72),
#  Row(antecedent=['7622210891747'], consequent=['5449000051547'], confidence=0.2, lift=91.09),
#  Row(antecedent=['7622210891747'], consequent=['0000000000145'], confidence=0.2, lift=2.83),
#  Row(antecedent=['5000128782838'], consequent=['0000000000145'], confidence=0.1875, lift=2.65),
#  Row(antecedent=['5000128597135'], consequent=['5000128983167'], confidence=0.0588, lift=8.54),
#  Row(antecedent=['5000128597135'], consequent=['5000128967259'], confidence=0.0588, lift=6.01),
#  Row(antecedent=['5000128597135'], consequent=['5000128785617'], confidence=0.0784, lift=1.5),
#  Row(antecedent=['5000128597135'], consequent=['0000000007535'], confidence=0.0588, lift=2.77),
#  Row(antecedent=['5000128597135'], consequent=['0000000000145'], confidence=0.098, lift=1.39),
#  Row(antecedent=['5000128597135'], consequent=['5000128597487'], confidence=0.0588, lift=22.67),
#  Row(antecedent=['5000128597135'], consequent=['5000128943710'], confidence=0.0588, lift=29.47),
#  Row(antecedent=['5000128739320'], consequent=['5000128822107'], confidence=0.2222, lift=159.05),
#  Row(antecedent=['5000128739320'], consequent=['5000328175973'], confidence=0.1667, lift=55.67),
#  Row(antecedent=['5000128739320'], consequent=['5000328192871'], confidence=0.1667, lift=31.51),
#  Row(antecedent=['5000128739320'], consequent=['5000128271165'], confidence=0.1667, lift=16.7),
#  Row(antecedent=['5000128739320'], consequent=['5000128785617'], confidence=0.1667, lift=3.18),
#  Row(antecedent=['5000128739320'], consequent=['5000328462622'], confidence=0.1667, lift=53.87),
#  Row(antecedent=['5000128739320'], consequent=['0000000000145'], confidence=0.1667, lift=2.36),
#  Row(antecedent=['5010092093441'], consequent=['5000128766708'], confidence=0.0833, lift=13.05),
#  Row(antecedent=['5010092093441'], consequent=['5000128785617'], confidence=0.0833, lift=1.59),
#  Row(antecedent=['5010092093441'], consequent=['5000128104524'], confidence=0.1944, lift=6.93),
#  Row(antecedent=['5010092093441'], consequent=['0000000000145'], confidence=0.1389, lift=1.97),
#  Row(antecedent=['5000205034546', '8712566328352'], consequent=['5000205039862'], confidence=1.0, lift=3340.0),
#  Row(antecedent=['5000205034546', '8712566328352'], consequent=['5010228013213'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000205034546', '8712566328352'], consequent=['5000128889889'], confidence=1.0, lift=1113.33),
#  Row(antecedent=['3073781011456'], consequent=['5000128785617'], confidence=0.75, lift=14.31),
#  Row(antecedent=['5000328452579'], consequent=['5000128785617'], confidence=0.1579, lift=3.01),
#  Row(antecedent=['5000128967242'], consequent=['5000128879606'], confidence=0.0732, lift=7.8),
#  Row(antecedent=['5000128967242'], consequent=['5000128967259'], confidence=0.0732, lift=7.48),
#  Row(antecedent=['5000128967242'], consequent=['5000128372190'], confidence=0.0976, lift=11.11),
#  Row(antecedent=['5000128967242'], consequent=['5000128861069'], confidence=0.0732, lift=7.48),
#  Row(antecedent=['5000128967242'], consequent=['0000000000145'], confidence=0.0976, lift=1.38),
#  Row(antecedent=['5000168209524'], consequent=['2083803000000'], confidence=0.3333, lift=11.36),
#  Row(antecedent=['5000168209425'], consequent=['5000168209302'], confidence=0.4286, lift=858.86),
#  Row(antecedent=['5000128779814'], consequent=['5000128744898'], confidence=0.0361, lift=8.42),
#  Row(antecedent=['5000128779814'], consequent=['5000128799980'], confidence=0.0361, lift=15.09),
#  Row(antecedent=['5000128779814'], consequent=['5000128655996'], confidence=0.0361, lift=9.53),
#  Row(antecedent=['5000128779814'], consequent=['5000128932912'], confidence=0.0361, lift=8.23),
#  Row(antecedent=['5000128779814'], consequent=['5000128712156'], confidence=0.0361, lift=9.53),
#  Row(antecedent=['5000128779814'], consequent=['0000000004711'], confidence=0.0482, lift=16.65),
#  Row(antecedent=['5000128779814'], consequent=['5000128317696'], confidence=0.0361, lift=9.29),
#  Row(antecedent=['5000128779814'], consequent=['5000128412810'], confidence=0.0361, lift=6.58),
#  Row(antecedent=['5000128779814'], consequent=['5000128640329'], confidence=0.0361, lift=15.75),
#  Row(antecedent=['5000128779814'], consequent=['5000128756617'], confidence=0.0602, lift=8.62),
#  Row(antecedent=['5000128779814'], consequent=['5000128879606'], confidence=0.0723, lift=7.71),
#  Row(antecedent=['5000128779814'], consequent=['5000128271165'], confidence=0.0482, lift=4.83),
#  Row(antecedent=['5000128779814'], consequent=['0000000000644'], confidence=0.0361, lift=1.72),
#  Row(antecedent=['5000128779814'], consequent=['5000128785617'], confidence=0.0361, lift=0.69),
#  Row(antecedent=['5000128779814'], consequent=['9770307757129'], confidence=0.0361, lift=2.08),
#  Row(antecedent=['5000128779814'], consequent=['5000128104524'], confidence=0.0843, lift=3.01),
#  Row(antecedent=['5000128779814'], consequent=['5000128861069'], confidence=0.0361, lift=3.7),
#  Row(antecedent=['5000128779814'], consequent=['0000000007535'], confidence=0.0723, lift=3.4),
#  Row(antecedent=['5000128779814'], consequent=['0000000000145'], confidence=0.1084, lift=1.53),
#  Row(antecedent=['5000128779814'], consequent=['5000128594202'], confidence=0.0361, lift=14.49),
#  Row(antecedent=['5000128779814'], consequent=['5000128540155'], confidence=0.0361, lift=11.68),
#  Row(antecedent=['5000128779814'], consequent=['5017600020074'], confidence=0.0361, lift=6.83),
#  Row(antecedent=['5000128779814'], consequent=['5000128959759'], confidence=0.0361, lift=10.35),
#  Row(antecedent=['5000128779814'], consequent=['5000128946834'], confidence=0.0361, lift=21.3),
#  Row(antecedent=['5000128779814'], consequent=['5000128983167'], confidence=0.0361, lift=5.25),
#  Row(antecedent=['5000128779814'], consequent=['7622210286956'], confidence=0.0361, lift=4.77),
#  Row(antecedent=['5000128779814'], consequent=['5000128267540'], confidence=0.1325, lift=21.08),
#  Row(antecedent=['5000128779814'], consequent=['5000128279840'], confidence=0.0361, lift=4.96),
#  Row(antecedent=['5000128779814'], consequent=['5010044002552'], confidence=0.0361, lift=9.29),
#  Row(antecedent=['5000128779814'], consequent=['5000128222860'], confidence=0.0361, lift=5.57),
#  Row(antecedent=['5000128766678'], consequent=['9770956806926'], confidence=0.0698, lift=23.3),
#  Row(antecedent=['5000128766678'], consequent=['5010044000121'], confidence=0.0698, lift=7.85),
#  Row(antecedent=['5000128766678'], consequent=['0000000000644'], confidence=0.0698, lift=3.33),
#  Row(antecedent=['5000128766678'], consequent=['5000128785617'], confidence=0.1163, lift=2.22),
#  Row(antecedent=['5000128766678'], consequent=['5000128756617'], confidence=0.0698, lift=9.99),
#  Row(antecedent=['0000000000095'], consequent=['0000000000345'], confidence=0.2, lift=125.25),
#  Row(antecedent=['5000128960113'], consequent=['5000128749855'], confidence=0.1765, lift=23.58),
#  Row(antecedent=['5000128960113'], consequent=['0000000000145'], confidence=0.2353, lift=3.33),
#  Row(antecedent=['5000128763448'], consequent=['5000128785617'], confidence=0.1667, lift=3.18),
#  Row(antecedent=['5000128786416'], consequent=['0000000004093'], confidence=0.1, lift=23.86),
#  Row(antecedent=['5000128786416'], consequent=['5000128271165'], confidence=0.1333, lift=13.36),
#  Row(antecedent=['5000128786416'], consequent=['0000000000644'], confidence=0.1, lift=4.77),
#  Row(antecedent=['5000128786416'], consequent=['0000000004562'], confidence=0.1333, lift=38.17),
#  Row(antecedent=['5000128786416'], consequent=['0000000000145'], confidence=0.1667, lift=2.36),
#  Row(antecedent=['5000128786416'], consequent=['5000128074339'], confidence=0.1, lift=45.55),
#  Row(antecedent=['5000128915618'], consequent=['5000128996488'], confidence=0.0566, lift=43.63),
#  Row(antecedent=['5000128915618'], consequent=['5000128698184'], confidence=0.0566, lift=51.56),
#  Row(antecedent=['5000128915618'], consequent=['5000328376677'], confidence=0.0566, lift=17.19),
#  Row(antecedent=['5000128915618'], consequent=['5000128104494'], confidence=0.0755, lift=3.67),
#  Row(antecedent=['5000128915618'], consequent=['5000128879606'], confidence=0.0943, lift=10.06),
#  Row(antecedent=['5000128915618'], consequent=['5000128271165'], confidence=0.0755, lift=7.56),
#  Row(antecedent=['5000128915618'], consequent=['5000128983167'], confidence=0.2264, lift=32.88),
#  Row(antecedent=['5000128915618'], consequent=['5000128922296'], confidence=0.2264, lift=26.69),
#  Row(antecedent=['5000128915618'], consequent=['0000000000644'], confidence=0.0755, lift=3.6),
#  Row(antecedent=['5000128915618'], consequent=['5000128785617'], confidence=0.0943, lift=1.8),
#  Row(antecedent=['5000128915618'], consequent=['5000128104524'], confidence=0.0566, lift=2.02),
#  Row(antecedent=['5000128915618'], consequent=['5000128756617'], confidence=0.0755, lift=10.8),
#  Row(antecedent=['5000128915618'], consequent=['5000128861069'], confidence=0.0943, lift=9.65),
#  Row(antecedent=['5000128915618'], consequent=['0000000007535'], confidence=0.0943, lift=4.44),
#  Row(antecedent=['5000128915618'], consequent=['0000000000145'], confidence=0.1509, lift=2.14),
#  Row(antecedent=['5000128915618'], consequent=['0000000004562'], confidence=0.0566, lift=16.2),
#  Row(antecedent=['5000128279932'], consequent=['5000128271165'], confidence=0.2609, lift=26.14),
#  Row(antecedent=['5000128279932'], consequent=['5000128785617'], confidence=0.1304, lift=2.49),
#  Row(antecedent=['5000128279932'], consequent=['0000000004562'], confidence=0.1304, lift=37.34),
#  Row(antecedent=['5000128279932'], consequent=['5000128279840'], confidence=0.1304, lift=17.9),
#  Row(antecedent=['5000128279932'], consequent=['0000000000145'], confidence=0.1304, lift=1.85),
#  Row(antecedent=['9770307017124', '2083803000000'], consequent=['9770307757129'], confidence=0.5, lift=28.79),
#  Row(antecedent=['5010718310211'], consequent=['5000128785617'], confidence=0.2857, lift=5.45),
#  Row(antecedent=['5000128940467'], consequent=['5000128785617'], confidence=0.1765, lift=3.37),
#  Row(antecedent=['5000128940467'], consequent=['0000000000145'], confidence=0.1765, lift=2.5),
#  Row(antecedent=['5036589200918'], consequent=['0000000007535'], confidence=0.6, lift=28.23),
#  Row(antecedent=['5000128629287'], consequent=['5000128620000'], confidence=0.25, lift=178.93),
#  Row(antecedent=['5000128664288'], consequent=['5000128833813'], confidence=0.1875, lift=78.28),
#  Row(antecedent=['5000128840545'], consequent=['5000128271165'], confidence=0.05, lift=5.01),
#  Row(antecedent=['5000128840545'], consequent=['0000000000644'], confidence=0.1, lift=4.77),
#  Row(antecedent=['5000128840545'], consequent=['5000128785617'], confidence=0.05, lift=0.95),
#  Row(antecedent=['5000128840545'], consequent=['9770307757129'], confidence=0.05, lift=2.88),
#  Row(antecedent=['5000128840545'], consequent=['0000000007535'], confidence=0.05, lift=2.35),
#  Row(antecedent=['5000128840545'], consequent=['0000000000145'], confidence=0.15, lift=2.12),
#  Row(antecedent=['7322540944945'], consequent=['2083803000000'], confidence=0.06, lift=2.04),
#  Row(antecedent=['7322540944945'], consequent=['5000128785617'], confidence=0.08, lift=1.53),
#  Row(antecedent=['7322540944945'], consequent=['0000000007535'], confidence=0.06, lift=2.82),
#  Row(antecedent=['7322540944945'], consequent=['0000000000145'], confidence=0.1, lift=1.42),
#  Row(antecedent=['5000128966399'], consequent=['2083803000000'], confidence=0.0909, lift=3.1),
#  Row(antecedent=['5000128966399'], consequent=['0000000000644'], confidence=0.1212, lift=5.78),
#  Row(antecedent=['5000128966399'], consequent=['5000128785617'], confidence=0.0909, lift=1.74),
#  Row(antecedent=['5000128966399'], consequent=['5000128966429'], confidence=0.0909, lift=22.22),
#  Row(antecedent=['5000128704137'], consequent=['5000128704052'], confidence=0.25, lift=139.17),
#  Row(antecedent=['5000328530215'], consequent=['5000128785617'], confidence=0.15, lift=2.86),
#  Row(antecedent=['5000328530215'], consequent=['0000000000145'], confidence=0.15, lift=2.12),
#  Row(antecedent=['0000000004048'], consequent=['0000000004053'], confidence=0.2308, lift=43.63),
#  Row(antecedent=['0000000004048'], consequent=['5000128989367'], confidence=0.2308, lift=44.47),
#  Row(antecedent=['0000000004048'], consequent=['5000128889902'], confidence=0.2308, lift=105.1),
#  Row(antecedent=['0000000004048'], consequent=['0000000007535'], confidence=0.4615, lift=21.71),
#  Row(antecedent=['5000128761390'], consequent=['5000128761833'], confidence=0.2273, lift=162.66),
#  Row(antecedent=['5000128761390'], consequent=['6191514300312'], confidence=0.1364, lift=5.72),
#  Row(antecedent=['5000128761390'], consequent=['0000000000644'], confidence=0.1364, lift=6.51),
#  Row(antecedent=['5000128761390'], consequent=['5000128785617'], confidence=0.1818, lift=3.47),
#  Row(antecedent=['5000181028133'], consequent=['5000128546775'], confidence=0.1429, lift=44.73),
#  Row(antecedent=['0000050128747', '5000128222860'], consequent=['5000128279796'], confidence=0.4286, lift=429.43),
#  Row(antecedent=['0000050128747', '5000128222860'], consequent=['5000128918305'], confidence=0.4286, lift=46.18),
#  Row(antecedent=['5000128733212'], consequent=['0000000000145'], confidence=0.25, lift=3.54),
#  Row(antecedent=['5000328475905'], consequent=['5000328201801'], confidence=0.1739, lift=108.91),
#  Row(antecedent=['5000128739184'], consequent=['5000328192871'], confidence=0.4286, lift=81.02),
#  Row(antecedent=['5000128879606', '5000128271165'], consequent=['5000128915618'], confidence=0.4286, lift=81.02),
#  Row(antecedent=['5000128104517', '5000128104524'], consequent=['9770307757129'], confidence=0.1304, lift=7.51),
#  Row(antecedent=['5000128104517', '5000128104524'], consequent=['5000128861069'], confidence=0.1304, lift=13.34),
#  Row(antecedent=['5000128457842'], consequent=['5000128922296'], confidence=0.1, lift=11.79),
#  Row(antecedent=['5000128457842'], consequent=['5000128983167'], confidence=0.08, lift=11.62),
#  Row(antecedent=['5000128457842'], consequent=['5000128785617'], confidence=0.16, lift=3.05),
#  Row(antecedent=['5000128457842'], consequent=['0000000007535'], confidence=0.12, lift=5.65),
#  Row(antecedent=['5000128457842'], consequent=['0000000000145'], confidence=0.1, lift=1.42),
#  Row(antecedent=['5000116105007', '5000116111473', '5000116111800', '5000116102464'], consequent=['5000116112050'], confidence=1.0, lift=556.67),
#  Row(antecedent=['5000128591713'], consequent=['5000128785617'], confidence=0.2727, lift=5.21),
#  Row(antecedent=['0000000000078'], consequent=['0000000000189'], confidence=0.125, lift=54.46),
#  Row(antecedent=['5000168001210'], consequent=['5000168001159'], confidence=0.1667, lift=55.67),
#  Row(antecedent=['5000168001210'], consequent=['5000128785617'], confidence=0.2222, lift=4.24),
#  Row(antecedent=['5000168001210'], consequent=['0000000000145'], confidence=0.2222, lift=3.15),
#  Row(antecedent=['5010238013616'], consequent=['5000116112050'], confidence=0.75, lift=417.5),
#  Row(antecedent=['5010238013616'], consequent=['5000116102464'], confidence=0.75, lift=626.25),
#  Row(antecedent=['5010238013616'], consequent=['5000116111473'], confidence=0.75, lift=1252.5),
#  Row(antecedent=['5010238013616'], consequent=['5000116111800'], confidence=0.75, lift=683.18),
#  Row(antecedent=['5000128818711'], consequent=['5000128785617'], confidence=0.2143, lift=4.09),
#  Row(antecedent=['5000128763899'], consequent=['5000128104524'], confidence=0.3333, lift=11.89),
#  Row(antecedent=['5000128782357'], consequent=['0000000000145'], confidence=0.2857, lift=4.04),
#  Row(antecedent=['8004260452816'], consequent=['5000128967259'], confidence=0.0698, lift=7.13),
#  Row(antecedent=['8004260452816'], consequent=['0000000000644'], confidence=0.0698, lift=3.33),
#  Row(antecedent=['8004260452816'], consequent=['5000128785617'], confidence=0.2093, lift=3.99),
#  Row(antecedent=['8004260452816'], consequent=['5010044000039'], confidence=0.0698, lift=15.89),
#  Row(antecedent=['8004260452816'], consequent=['5000128104524'], confidence=0.1163, lift=4.15),
#  Row(antecedent=['8004260452816'], consequent=['5010044000275'], confidence=0.0698, lift=13.98),
#  Row(antecedent=['8004260452816'], consequent=['0000000007535'], confidence=0.0698, lift=3.28),
#  Row(antecedent=['8004260452816'], consequent=['0000000000145'], confidence=0.1628, lift=2.3),
#  Row(antecedent=['9771056348958', '9770957623928'], consequent=['9770307268922'], confidence=1.0, lift=43.38),
#  Row(antecedent=['5000128431156'], consequent=['5000128785617'], confidence=0.2857, lift=5.45),
#  Row(antecedent=['2083801000002', '6100000000193'], consequent=['2083803000000'], confidence=0.75, lift=25.56),
#  Row(antecedent=['5000128785587'], consequent=['5000128785617'], confidence=0.4, lift=7.63),
#  Row(antecedent=['5000168193984'], consequent=['5000128104494'], confidence=0.1034, lift=5.03),
#  Row(antecedent=['5000168193984'], consequent=['5000168194189'], confidence=0.1724, lift=36.76),
#  Row(antecedent=['5000168193984'], consequent=['5000128785617'], confidence=0.1034, lift=1.97),
#  Row(antecedent=['5000168193984'], consequent=['0000000000145'], confidence=0.1034, lift=1.46),
#  Row(antecedent=['5010238013616', '5000116111473', '5000116111800', '5000116112050'], consequent=['5000116102464'], confidence=1.0, lift=835.0),
#  Row(antecedent=['5000328681443'], consequent=['5000128785617'], confidence=0.1176, lift=2.25),
#  Row(antecedent=['5000128600446'], consequent=['0000000000145'], confidence=0.4286, lift=6.07),
#  Row(antecedent=['5000128749855'], consequent=['5000128104494'], confidence=0.04, lift=1.95),
#  Row(antecedent=['5000128749855'], consequent=['5010044000121'], confidence=0.04, lift=4.5),
#  Row(antecedent=['5000128749855'], consequent=['5000128785617'], confidence=0.08, lift=1.53),
#  Row(antecedent=['5000128749855'], consequent=['5000128104524'], confidence=0.0533, lift=1.9),
#  Row(antecedent=['5000128749855'], consequent=['0000000007535'], confidence=0.04, lift=1.88),
#  Row(antecedent=['5000128749855'], consequent=['0000000000145'], confidence=0.0933, lift=1.32),
#  Row(antecedent=['5000128749855'], consequent=['5740900805408'], confidence=0.04, lift=8.91),
#  Row(antecedent=['5000128749855'], consequent=['5000168194189'], confidence=0.04, lift=8.53),
#  Row(antecedent=['5000128749855'], consequent=['5000128960113'], confidence=0.04, lift=23.58),
#  Row(antecedent=['5000128749855'], consequent=['5012035950040'], confidence=0.04, lift=20.04),
#  Row(antecedent=['5000128749855'], consequent=['5000295142893'], confidence=0.04, lift=14.31),
#  Row(antecedent=['5000128749855'], consequent=['5000128279840'], confidence=0.04, lift=5.49),
#  Row(antecedent=['5740900805408'], consequent=['5000128879606'], confidence=0.0667, lift=7.11),
#  Row(antecedent=['5740900805408'], consequent=['5000128104494'], confidence=0.0889, lift=4.32),
#  Row(antecedent=['5740900805408'], consequent=['5000128749855'], confidence=0.0667, lift=8.91),
#  Row(antecedent=['5740900805408'], consequent=['0000000000644'], confidence=0.0667, lift=3.18),
#  Row(antecedent=['5740900805408'], consequent=['5000128785617'], confidence=0.1111, lift=2.12),
#  Row(antecedent=['5740900805408'], consequent=['0000000000145'], confidence=0.1778, lift=2.52),
#  Row(antecedent=['5740900805408'], consequent=['0000000004093'], confidence=0.0889, lift=21.21),
#  Row(antecedent=['5031390114690'], consequent=['6100000000193'], confidence=0.3333, lift=29.3),
#  Row(antecedent=['5010228001852'], consequent=['5000128104494'], confidence=0.1071, lift=5.21),
#  Row(antecedent=['5010228001852'], consequent=['6191514300312'], confidence=0.1071, lift=4.49),
#  Row(antecedent=['5010228001852'], consequent=['0000000000145'], confidence=0.1786, lift=2.53),
#  Row(antecedent=['5000128611800'], consequent=['5000128785617'], confidence=0.1875, lift=3.58),
#  Row(antecedent=['5000128611800'], consequent=['0000000000145'], confidence=0.25, lift=3.54),
#  Row(antecedent=['9770307017124'], consequent=['5000128104494'], confidence=0.0612, lift=2.98),
#  Row(antecedent=['9770307017124'], consequent=['2083803000000'], confidence=0.1224, lift=4.17),
#  Row(antecedent=['9770307017124'], consequent=['9770307268922'], confidence=0.1224, lift=5.31),
#  Row(antecedent=['9770307017124'], consequent=['9770956805424'], confidence=0.0816, lift=8.8),
#  Row(antecedent=['9770307017124'], consequent=['9770307757129'], confidence=0.1633, lift=9.4),
#  Row(antecedent=['5000128861106'], consequent=['0000000000145'], confidence=0.1905, lift=2.7),
#  Row(antecedent=['5000128861106'], consequent=['5000128695688'], confidence=0.1429, lift=143.14),
#  Row(antecedent=['6191514300329'], consequent=['6191514300343'], confidence=0.0789, lift=37.67),
#  Row(antecedent=['6191514300329'], consequent=['6191514300312'], confidence=0.2632, lift=11.03),
#  Row(antecedent=['5000177474777'], consequent=['2083803000000'], confidence=0.12, lift=4.09),
#  Row(antecedent=['5000128317696', '0000000007535'], consequent=['5000128712156'], confidence=0.6, lift=158.21),
#  Row(antecedent=['5031390114621'], consequent=['5031390114546'], confidence=0.0962, lift=40.14),
#  Row(antecedent=['5031390114621'], consequent=['5031390114683'], confidence=0.0577, lift=25.13),
#  Row(antecedent=['5031390114621'], consequent=['2083801000002'], confidence=0.0577, lift=6.96),
#  Row(antecedent=['5031390114621'], consequent=['6100000000193'], confidence=0.1346, lift=11.83),
#  Row(antecedent=['5031390114621'], consequent=['2083803000000'], confidence=0.1923, lift=6.55),
#  Row(antecedent=['5031390114621'], consequent=['5031390114676'], confidence=0.0769, lift=28.55),
#  Row(antecedent=['2083807000006', '2083803000000'], consequent=['6100000000193'], confidence=0.3, lift=26.37),
#  Row(antecedent=['2083807000006', '2083803000000'], consequent=['2083804000009'], confidence=0.4, lift=83.5),
#  Row(antecedent=['5015552555132'], consequent=['5000128785617'], confidence=0.2, lift=3.82),
#  Row(antecedent=['5015552555132'], consequent=['0000000000145'], confidence=0.2, lift=2.83),
#  Row(antecedent=['5000116105007', '5000116111473', '5000116102464', '5000116112050'], consequent=['5000116111800'], confidence=1.0, lift=910.91),
#  Row(antecedent=['5000128661393'], consequent=['5010718402909'], confidence=0.0714, lift=31.12),
#  Row(antecedent=['5000128661393'], consequent=['5000128785617'], confidence=0.0952, lift=1.82),
#  Row(antecedent=['5000128661393'], consequent=['0000000000145'], confidence=0.119, lift=1.68),
#  Row(antecedent=['5054267002333'], consequent=['5000328698823'], confidence=0.15, lift=42.94),
#  Row(antecedent=['5000143915525'], consequent=['5000128104494'], confidence=0.25, lift=12.16),
#  Row(antecedent=['5000128859189'], consequent=['0000000000145'], confidence=0.3333, lift=4.72),
#  Row(antecedent=['4002359644702'], consequent=['5000128737111'], confidence=0.4286, lift=858.86),
#  Row(antecedent=['4002359644702'], consequent=['5000128960021'], confidence=0.4286, lift=252.61),
#  Row(antecedent=['5000128999847'], consequent=['5000128983167'], confidence=0.2308, lift=33.51),
#  Row(antecedent=['5000128999847'], consequent=['0000000000644'], confidence=0.2308, lift=11.01),
#  Row(antecedent=['5000128999847'], consequent=['0000000007535'], confidence=0.3077, lift=14.47),
#  Row(antecedent=['5000205039862'], consequent=['5010228013213'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000205039862'], consequent=['5000128889889'], confidence=1.0, lift=1113.33),
#  Row(antecedent=['5000205039862'], consequent=['8712566328352'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000205039862'], consequent=['5000205034546'], confidence=1.0, lift=2004.0),
#  Row(antecedent=['5000128766999'], consequent=['5000128104524'], confidence=0.2, lift=7.13),
#  Row(antecedent=['5000128766999'], consequent=['0000000000145'], confidence=0.25, lift=3.54),
#  Row(antecedent=['5000128766999'], consequent=['5000128942348'], confidence=0.15, lift=214.71),
#  Row(antecedent=['5000128879606'], consequent=['5000128967648'], confidence=0.0426, lift=12.18),
#  Row(antecedent=['5000128879606'], consequent=['5000128998031'], confidence=0.0532, lift=9.19),
#  Row(antecedent=['5000128879606'], consequent=['0000000004729'], confidence=0.0532, lift=11.59),
#  Row(antecedent=['5000128879606'], consequent=['5000128989367'], confidence=0.0426, lift=8.2),
#  Row(antecedent=['5000128879606'], consequent=['5000128808286'], confidence=0.0426, lift=19.38),
#  Row(antecedent=['5000128879606'], consequent=['5000128987868'], confidence=0.0426, lift=15.79),
#  Row(antecedent=['5000128879606'], consequent=['5000128799980'], confidence=0.0426, lift=17.77),
#  Row(antecedent=['5000128879606'], consequent=['5000128932912'], confidence=0.0532, lift=12.11),
#  Row(antecedent=['5000128879606'], consequent=['5000128922296'], confidence=0.0532, lift=6.27),
#  Row(antecedent=['5000128879606'], consequent=['5000128915618'], confidence=0.0532, lift=10.06),
#  Row(antecedent=['5000128879606'], consequent=['5000128475389'], confidence=0.0426, lift=19.38),
#  Row(antecedent=['5000128879606'], consequent=['5000328583839'], confidence=0.0319, lift=11.42),
#  Row(antecedent=['5000128879606'], consequent=['5010044005126'], confidence=0.0426, lift=5.84),
#  Row(antecedent=['5000128879606'], consequent=['5740900805408'], confidence=0.0319, lift=7.11),
#  Row(antecedent=['5000128879606'], consequent=['5000128912617'], confidence=0.0319, lift=24.6),
#  Row(antecedent=['5000128879606'], consequent=['5000128918305'], confidence=0.0532, lift=5.73),
#  Row(antecedent=['5000128879606'], consequent=['5000128412810'], confidence=0.0426, lift=7.75),
#  Row(antecedent=['5000128879606'], consequent=['5000128967242'], confidence=0.0319, lift=7.8),
#  Row(antecedent=['5000128879606'], consequent=['5000128756617'], confidence=0.0638, lift=9.14),
#  Row(antecedent=['5000128879606'], consequent=['5000128779814'], confidence=0.0638, lift=7.71),
#  Row(antecedent=['5000128879606'], consequent=['5000128540155'], confidence=0.0319, lift=10.32),
#  Row(antecedent=['5000128879606'], consequent=['5000128959629'], confidence=0.0319, lift=9.14),
#  Row(antecedent=['5000128879606'], consequent=['5000128606387'], confidence=0.0532, lift=15.68),
#  Row(antecedent=['5000128879606'], consequent=['5000128104494'], confidence=0.0745, lift=3.62),
#  Row(antecedent=['5000128879606'], consequent=['5000128271165'], confidence=0.0745, lift=7.46),
#  Row(antecedent=['5000128879606'], consequent=['0000000000644'], confidence=0.0851, lift=4.06),
#  Row(antecedent=['5000128879606'], consequent=['5000128785617'], confidence=0.0319, lift=0.61),
#  Row(antecedent=['5000128879606'], consequent=['9770307757129'], confidence=0.0319, lift=1.84),
#  Row(antecedent=['5000128879606'], consequent=['5000128104524'], confidence=0.0638, lift=2.28),
#  Row(antecedent=['5000128879606'], consequent=['5000128861069'], confidence=0.0426, lift=4.35),
#  Row(antecedent=['5000128879606'], consequent=['0000000007535'], confidence=0.1383, lift=6.51),
#  Row(antecedent=['5000128879606'], consequent=['0000000000145'], confidence=0.117, lift=1.66),
#  Row(antecedent=['5000128879606'], consequent=['5000128267601'], confidence=0.0426, lift=32.8),
#  Row(antecedent=['5000128879606'], consequent=['5000128989640'], confidence=0.0532, lift=28.05),
#  Row(antecedent=['5000128879606'], consequent=['5000128566193'], confidence=0.0426, lift=13.75),
#  Row(antecedent=['5000128879606'], consequent=['5000128279840'], confidence=0.0745, lift=10.22),
#  Row(antecedent=['5000128879606'], consequent=['5000128222860'], confidence=0.1596, lift=24.6),
#  Row(antecedent=['5000116111473'], consequent=['5000116105007'], confidence=0.6667, lift=1336.0),
#  Row(antecedent=['5000116111473'], consequent=['5010238013616'], confidence=0.5, lift=1252.5),
#  Row(antecedent=['5000116111473'], consequent=['5000116112050'], confidence=0.8333, lift=463.89),
#  Row(antecedent=['5000116111473'], consequent=['5000116102464'], confidence=0.8333, lift=695.83),
#  Row(antecedent=['5000116111473'], consequent=['5000116111800'], confidence=0.8333, lift=759.09),
#  Row(antecedent=['7622210764584'], consequent=['5000128785617'], confidence=0.2143, lift=4.09),
#  Row(antecedent=['5000128620000'], consequent=['5000128785617'], confidence=0.3571, lift=6.82),
#  Row(antecedent=['5000128620000'], consequent=['5000128907613'], confidence=0.2143, lift=143.14),
#  Row(antecedent=['5000128620000'], consequent=['5000128629287'], confidence=0.2143, lift=178.93),
#  Row(antecedent=['9770956805424'], consequent=['9770307017124'], confidence=0.043, lift=8.8),
#  Row(antecedent=['9770956805424'], consequent=['0000000004729'], confidence=0.0323, lift=7.03),
#  Row(antecedent=['9770956805424'], consequent=['9770957623928'], confidence=0.043, lift=6.63),
#  Row(antecedent=['9770956805424'], consequent=['2083803000000'], confidence=0.0968, lift=3.3),
#  Row(antecedent=['9770956805424'], consequent=['9770307268922'], confidence=0.1505, lift=6.53),
#  Row(antecedent=['9770956805424'], consequent=['5000128785617'], confidence=0.0323, lift=0.62),
#  Row(antecedent=['9770956805424'], consequent=['9770307757129'], confidence=0.1075, lift=6.19),
#  Row(antecedent=['9770956805424'], consequent=['5000128104524'], confidence=0.0645, lift=2.3),
#  Row(antecedent=['9770956805424'], consequent=['0000000000145'], confidence=0.0323, lift=0.46),
#  Row(antecedent=['5000128712156', '0000000007535'], consequent=['5000128317696'], confidence=0.75, lift=192.69),
#  Row(antecedent=['5010044005126'], consequent=['9770957623928'], confidence=0.0548, lift=8.45),
#  Row(antecedent=['5010044005126'], consequent=['5000128879606'], confidence=0.0548, lift=5.84),
#  Row(antecedent=['5010044005126'], consequent=['5000128104494'], confidence=0.0548, lift=2.67),
#  Row(antecedent=['5010044005126'], consequent=['5000128271165'], confidence=0.0411, lift=4.12),
#  Row(antecedent=['5010044005126'], consequent=['6191514300312'], confidence=0.0411, lift=1.72),
#  Row(antecedent=['5010044005126'], consequent=['0000000000644'], confidence=0.0822, lift=3.92),
#  Row(antecedent=['5010044005126'], consequent=['5000128967259'], confidence=0.0548, lift=5.6),
#  Row(antecedent=['5010044005126'], consequent=['5000128785617'], confidence=0.1096, lift=2.09),
#  Row(antecedent=['5010044005126'], consequent=['5000128104517'], confidence=0.0411, lift=3.68),
#  Row(antecedent=['5010044005126'], consequent=['5000128104524'], confidence=0.1233, lift=4.4),
#  Row(antecedent=['5010044005126'], consequent=['0000000000145'], confidence=0.0959, lift=1.36),
#  Row(antecedent=['5010044005126'], consequent=['0000050404957'], confidence=0.0411, lift=11.13),
#  Row(antecedent=['5010044005126'], consequent=['5017600020074'], confidence=0.0411, lift=7.77),
#  Row(antecedent=['5000128996488'], consequent=['5000128915618'], confidence=0.2308, lift=43.63),
#  Row(antecedent=['5000128996488'], consequent=['0000000000145'], confidence=0.3077, lift=4.35),
#  Row(antecedent=['5000128703376'], consequent=['0000000000145'], confidence=0.6, lift=8.49),
#  Row(antecedent=['5000157062635'], consequent=['5000157062673'], confidence=0.75, lift=197.76),
#  Row(antecedent=['5000127780064'], consequent=['0000000000145'], confidence=0.4444, lift=6.29),
#  Row(antecedent=['9771358588120'], consequent=['9770307268922'], confidence=0.4545, lift=19.72),
#  Row(antecedent=['5000128447607'], consequent=['0000000000145'], confidence=0.2308, lift=3.27),
#  Row(antecedent=['9770307268922', '0000000000145'], consequent=['9770957623928'], confidence=0.2727, lift=42.04),
#  Row(antecedent=['7622210448101'], consequent=['0000000000145'], confidence=0.1579, lift=2.23),
#  Row(antecedent=['5000128956376'], consequent=['0000000000145'], confidence=0.2273, lift=3.22),
#  Row(antecedent=['5000128922777'], consequent=['5000328123301'], confidence=0.1364, lift=50.61),
#  Row(antecedent=['5000128922777'], consequent=['5000128785617'], confidence=0.1818, lift=3.47),
#  Row(antecedent=['5000128653947'], consequent=['0000000000145'], confidence=0.2727, lift=3.86),
#  Row(antecedent=['8004260452816', '0000000000145'], consequent=['5000128104524'], confidence=0.4286, lift=15.28),
#  Row(antecedent=['5000128661911', '5000128663250'], consequent=['5000128663076'], confidence=0.5, lift=172.76),
#  Row(antecedent=['5000128661911', '5000128663250'], consequent=['0000000000145'], confidence=0.5, lift=7.08),
#  Row(antecedent=['3456774773034'], consequent=['5000128104524'], confidence=0.4286, lift=15.28),
#  Row(antecedent=['3456774773034'], consequent=['0000000000145'], confidence=0.4286, lift=6.07),
#  Row(antecedent=['7622210286314'], consequent=['5000159457873'], confidence=0.3, lift=250.5),
#  Row(antecedent=['5000116111800', '5000116102464', '5000116112050'], consequent=['5000116105007'], confidence=0.8, lift=1603.2),
#  Row(antecedent=['5000116111800', '5000116102464', '5000116112050'], consequent=['5010238013616'], confidence=0.6, lift=1503.0),
#  Row(antecedent=['5000116111800', '5000116102464', '5000116112050'], consequent=['5000116111473'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000128744898'], consequent=['5000128989367'], confidence=0.1163, lift=22.41),
#  Row(antecedent=['5000128744898'], consequent=['5000128267540'], confidence=0.1163, lift=18.49),
#  Row(antecedent=['5000128744898'], consequent=['5000128785617'], confidence=0.093, lift=1.78),
#  Row(antecedent=['5000128744898'], consequent=['5000128104524'], confidence=0.093, lift=3.32),
#  Row(antecedent=['5000128744898'], consequent=['5000128779814'], confidence=0.0698, lift=8.42),
#  Row(antecedent=['5000128744898'], consequent=['0000000000145'], confidence=0.2791, lift=3.95),
#  Row(antecedent=['5000128744898'], consequent=['5000128712156'], confidence=0.093, lift=24.53),
#  Row(antecedent=['5000128744898'], consequent=['5011308505024'], confidence=0.0698, lift=99.87),
#  Row(antecedent=['5000128744898'], consequent=['5000128959629'], confidence=0.0698, lift=19.97),
#  Row(antecedent=['9770957623928'], consequent=['5000128775489'], confidence=0.0462, lift=9.07),
#  Row(antecedent=['9770957623928'], consequent=['2083803000000'], confidence=0.0615, lift=2.1),
#  Row(antecedent=['9770957623928'], consequent=['9770307268922'], confidence=0.2769, lift=12.01),
#  Row(antecedent=['9770957623928'], consequent=['5010044005126'], confidence=0.0615, lift=8.45),
#  Row(antecedent=['9770957623928'], consequent=['9770956805424'], confidence=0.0615, lift=6.63),
#  Row(antecedent=['9770957623928'], consequent=['9770307757129'], confidence=0.0462, lift=2.66),
#  Row(antecedent=['9770957623928'], consequent=['5000128372190'], confidence=0.0615, lift=7.01),
#  Row(antecedent=['9770957623928'], consequent=['0000000000145'], confidence=0.1077, lift=1.52),
#  Row(antecedent=['9770957623928'], consequent=['9772044733053'], confidence=0.0615, lift=9.63),
#  Row(antecedent=['9770957623928'], consequent=['9771056348958'], confidence=0.0462, lift=66.07),
#  Row(antecedent=['0000050129119', '5000128279840'], consequent=['5000128271165'], confidence=0.5, lift=50.1),
#  Row(antecedent=['0000040084107'], consequent=['5000128785617'], confidence=0.1333, lift=2.54),
#  Row(antecedent=['4002359634826'], consequent=['5000128632416'], confidence=0.2308, lift=77.08),
#  Row(antecedent=['5000118203664'], consequent=['8722700153276'], confidence=0.1176, lift=90.68),
#  Row(antecedent=['5000118203664'], consequent=['0000000000644'], confidence=0.0882, lift=4.21),
#  Row(antecedent=['5000118203664'], consequent=['5000128785617'], confidence=0.1471, lift=2.81),
#  Row(antecedent=['5000118203664'], consequent=['5000128590990'], confidence=0.0882, lift=19.65),
#  Row(antecedent=['5000118203664'], consequent=['0000000000145'], confidence=0.1176, lift=1.67),
#  Row(antecedent=['5000128980579'], consequent=['5000128584364'], confidence=0.25, lift=139.17),
#  Row(antecedent=['5060466510210'], consequent=['0000000000145'], confidence=0.125, lift=1.77),
#  Row(antecedent=['5000128811200'], consequent=['5000128271165'], confidence=0.1579, lift=15.82),
#  Row(antecedent=['5000128811200'], consequent=['5000128785617'], confidence=0.2105, lift=4.02),
#  Row(antecedent=['5011308550192'], consequent=['0000000000145'], confidence=1.0, lift=14.15),
#  Row(antecedent=['5000221604983'], consequent=['5000128785617'], confidence=0.4286, lift=8.18),
#  Row(antecedent=['5000128725477'], consequent=['5000128104494'], confidence=0.1, lift=4.86),
#  Row(antecedent=['5000128725477'], consequent=['0000000007535'], confidence=0.1, lift=4.7),
#  Row(antecedent=['5000128725477'], consequent=['0000000000145'], confidence=0.1333, lift=1.89),
#  Row(antecedent=['5000128546775'], consequent=['5000128749435'], confidence=0.0938, lift=44.73),
#  Row(antecedent=['5000128546775'], consequent=['5000181028133'], confidence=0.0938, lift=44.73),
#  Row(antecedent=['5000128546775'], consequent=['5000128932912'], confidence=0.0938, lift=21.35),
#  Row(antecedent=['5000128546775'], consequent=['0000000000644'], confidence=0.0938, lift=4.47),
#  Row(antecedent=['5000128546775'], consequent=['5000128267540'], confidence=0.0938, lift=14.91),
#  Row(antecedent=['5000128546775'], consequent=['5000128785617'], confidence=0.2813, lift=5.37),
#  Row(antecedent=['5000128546775'], consequent=['5000128850094'], confidence=0.0938, lift=26.09),
#  Row(antecedent=['5000128546775'], consequent=['0000000000145'], confidence=0.1563, lift=2.21),
#  Row(antecedent=['5411188112778'], consequent=['0000000000145'], confidence=0.2, lift=2.83),
#  Row(antecedent=['5000159455343'], consequent=['5000159484527'], confidence=0.0833, lift=20.37),
#  Row(antecedent=['5000159455343'], consequent=['5000159481472'], confidence=0.0833, lift=26.94),
#  Row(antecedent=['5000159455343'], consequent=['7622210700070'], confidence=0.0625, lift=44.73),
#  Row(antecedent=['5000159455343'], consequent=['5000328192871'], confidence=0.0833, lift=15.75),
#  Row(antecedent=['5000159455343'], consequent=['6191514300312'], confidence=0.1042, lift=4.37),
#  Row(antecedent=['5000159455343'], consequent=['0000000000644'], confidence=0.0833, lift=3.98),
#  Row(antecedent=['5000159455343'], consequent=['5000128785617'], confidence=0.125, lift=2.39),
#  Row(antecedent=['5000159455343'], consequent=['0000000000145'], confidence=0.125, lift=1.77),
#  Row(antecedent=['5000159455343'], consequent=['5000159394499'], confidence=0.0625, lift=27.23),
#  Row(antecedent=['5000128661942'], consequent=['5000128663090'], confidence=0.2, lift=286.29),
#  Row(antecedent=['5000128661942'], consequent=['5000128663076'], confidence=0.36, lift=124.39),
#  Row(antecedent=['5000128661942'], consequent=['5000128663250'], confidence=0.2, lift=74.22),
#  Row(antecedent=['5000128661942'], consequent=['5000128661911'], confidence=0.36, lift=138.74),
#  Row(antecedent=['5000128661942'], consequent=['0000000000145'], confidence=0.16, lift=2.26),
#  Row(antecedent=['5000128222860', '5000128879606'], consequent=['0000000007535'], confidence=0.2, lift=9.41),
#  Row(antecedent=['5000128222860', '5000128879606'], consequent=['0000000000145'], confidence=0.2, lift=2.83),
#  Row(antecedent=['5000128222860', '5000128879606'], consequent=['5000128922296'], confidence=0.2, lift=23.58),
#  Row(antecedent=['5000128222860', '5000128879606'], consequent=['5000128918305'], confidence=0.2, lift=21.55),
#  Row(antecedent=['5000128943710'], consequent=['5000128963701'], confidence=0.15, lift=167.0),
#  Row(antecedent=['5000128943710'], consequent=['5000128597135'], confidence=0.15, lift=29.47),
#  Row(antecedent=['5000128943710'], consequent=['0000000000145'], confidence=0.25, lift=3.54),
#  Row(antecedent=['5000128829519'], consequent=['0000000000145'], confidence=0.6, lift=8.49),
#  Row(antecedent=['5000328308166'], consequent=['0000000000145'], confidence=0.12, lift=1.7),
#  Row(antecedent=['5000328308166'], consequent=['5000328543178'], confidence=0.12, lift=109.31),
#  Row(antecedent=['5034660518679'], consequent=['0000000000145'], confidence=0.2308, lift=3.27),
#  Row(antecedent=['5000168187167'], consequent=['5000168194127'], confidence=0.1379, lift=46.07),
#  Row(antecedent=['5000168187167'], consequent=['0000000000644'], confidence=0.1379, lift=6.58),
#  Row(antecedent=['5000168187167'], consequent=['5000128785617'], confidence=0.1379, lift=2.63),
#  Row(antecedent=['5000168187167'], consequent=['5000168187280'], confidence=0.1724, lift=59.57),
#  Row(antecedent=['5000168187167'], consequent=['0000000000145'], confidence=0.1034, lift=1.46),
#  Row(antecedent=['5000168187167'], consequent=['5010035066556'], confidence=0.1034, lift=103.66),
#  Row(antecedent=['5000232868589'], consequent=['6191514300312'], confidence=0.375, lift=15.72),
#  Row(antecedent=['5000128799980', '5000128861069'], consequent=['5000128998031'], confidence=1.0, lift=172.76),
#  Row(antecedent=['5000128667586'], consequent=['5000128994507'], confidence=0.1176, lift=39.29),
#  Row(antecedent=['5000128667586'], consequent=['5000128763424'], confidence=0.0882, lift=42.1),
#  Row(antecedent=['5000128667586'], consequent=['0000000000644'], confidence=0.0882, lift=4.21),
#  Row(antecedent=['5000128667586'], consequent=['5000128785617'], confidence=0.0882, lift=1.68),
#  Row(antecedent=['5000128667586'], consequent=['5000128590990'], confidence=0.0882, lift=19.65),
#  Row(antecedent=['5000128667586'], consequent=['0000000000145'], confidence=0.1176, lift=1.67),
#  Row(antecedent=['5000295008069'], consequent=['0000000000644'], confidence=0.1154, lift=5.51),
#  Row(antecedent=['5000295008069'], consequent=['5000128785617'], confidence=0.1538, lift=2.94),
#  Row(antecedent=['5000295008069'], consequent=['0000000000145'], confidence=0.1923, lift=2.72),
#  Row(antecedent=['5000205039862', '8712566328352', '5000128889889'], consequent=['5010228013213'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000205039862', '8712566328352', '5000128889889'], consequent=['5000205034546'], confidence=1.0, lift=2004.0),
#  Row(antecedent=['5000128915618', '5000128983167'], consequent=['5000128785617'], confidence=0.25, lift=4.77),
#  Row(antecedent=['5000128629744'], consequent=['5000128785617'], confidence=0.1667, lift=3.18),
#  Row(antecedent=['5000128629744'], consequent=['0000000000145'], confidence=0.1667, lift=2.36),
#  Row(antecedent=['5000128950855'], consequent=['0000000000145'], confidence=0.375, lift=5.31),
#  Row(antecedent=['5000328376677'], consequent=['5000128967259'], confidence=0.1515, lift=15.49),
#  Row(antecedent=['5000328376677'], consequent=['5000128915618'], confidence=0.0909, lift=17.19),
#  Row(antecedent=['5000328376677'], consequent=['5000128785617'], confidence=0.1515, lift=2.89),
#  Row(antecedent=['5000328376677'], consequent=['0000050404957'], confidence=0.0909, lift=24.62),
#  Row(antecedent=['5000328376677'], consequent=['0000000000145'], confidence=0.1212, lift=1.72),
#  Row(antecedent=['5000328376677'], consequent=['5000328375373'], confidence=0.0909, lift=41.4),
#  Row(antecedent=['5000328376677'], consequent=['5000328375618'], confidence=0.1212, lift=71.44),
#  Row(antecedent=['9771056348958', '9770307268922'], consequent=['9770957623928'], confidence=1.0, lift=154.15),
#  Row(antecedent=['5000328123301'], consequent=['5000128922777'], confidence=0.1111, lift=50.61),
#  Row(antecedent=['5000328123301'], consequent=['5000128700375'], confidence=0.1111, lift=27.15),
#  Row(antecedent=['5000328123301'], consequent=['0000054491496'], confidence=0.1111, lift=18.87),
#  Row(antecedent=['5000205034546', '5000128889889'], consequent=['5000205039862'], confidence=1.0, lift=3340.0),
#  Row(antecedent=['5000205034546', '5000128889889'], consequent=['5010228013213'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000205034546', '5000128889889'], consequent=['8712566328352'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5053990138746'], consequent=['5053990138661'], confidence=0.2222, lift=74.22),
#  Row(antecedent=['5053990138746'], consequent=['5053990138722'], confidence=0.1667, lift=47.71),
#  Row(antecedent=['5000128769433'], consequent=['5000354201547'], confidence=0.3, lift=375.75),
#  Row(antecedent=['5000205034546', '5010228013213'], consequent=['5000205039862'], confidence=1.0, lift=3340.0),
#  Row(antecedent=['5000205034546', '5010228013213'], consequent=['5000128889889'], confidence=1.0, lift=1113.33),
#  Row(antecedent=['5000205034546', '5010228013213'], consequent=['8712566328352'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5000431027084'], consequent=['0000000000145'], confidence=0.1765, lift=2.5),
#  Row(antecedent=['5029053561363'], consequent=['0000000000145'], confidence=0.2727, lift=3.86),
#  Row(antecedent=['5000431027312'], consequent=['5000128785617'], confidence=0.125, lift=2.39),
#  Row(antecedent=['5000328347790', '0000000000145'], consequent=['5000328698823'], confidence=0.2308, lift=66.07),
#  Row(antecedent=['5000128580915'], consequent=['0000000007535'], confidence=0.1538, lift=7.24),
#  Row(antecedent=['8712566328352'], consequent=['5000205039862'], confidence=0.5, lift=1670.0),
#  Row(antecedent=['8712566328352'], consequent=['5010228013213'], confidence=0.5, lift=835.0),
#  Row(antecedent=['8712566328352'], consequent=['5000128889889'], confidence=0.5, lift=556.67),
#  Row(antecedent=['8712566328352'], consequent=['5000205034546'], confidence=0.5, lift=1002.0),
#  Row(antecedent=['5010238013616', '5000116102464'], consequent=['5000116112050'], confidence=1.0, lift=556.67),
#  Row(antecedent=['5010238013616', '5000116102464'], consequent=['5000116111473'], confidence=1.0, lift=1670.0),
#  Row(antecedent=['5010238013616', '5000116102464'], consequent=['5000116111800'], confidence=1.0, lift=910.91),
#  Row(antecedent=['5052320755837'], consequent=['5000128785617'], confidence=0.0566, lift=1.08),
#  Row(antecedent=['5000128891189'], consequent=['0000000004390'], confidence=0.75, lift=357.86),
# ...
#  Row(antecedent=['6100000000193'], consequent=['5031390114324'], confidence=0.0702, lift=24.25),
#  Row(antecedent=['6100000000193'], consequent=['5031390114638'], confidence=0.0351, lift=31.96),
#  Row(antecedent=['6100000000193'], consequent=['5031390114621'], confidence=0.0614, lift=11.83),
#  Row(antecedent=['6100000000193'], consequent=['5031390114676'], confidence=0.0614, lift=22.79),
#  Row(antecedent=['0000050128747', '5000128918305'], consequent=['5000128267601'], confidence=0.375, lift=289.04),
#  Row(antecedent=['0000050128747', '5000128918305'], consequent=['5000128222860'], confidence=0.375, lift=57.81),
#  Row(antecedent=['5011308505024'], consequent=['5000128744898'], confidence=0.4286, lift=99.87),
#  Row(antecedent=['5031390114706'], consequent=['6100000000193'], confidence=0.2222, lift=19.53),
#  Row(antecedent=['5031390114706'], consequent=['5031390113662'], confidence=0.1667, lift=151.82),
#  Row(antecedent=['5010228013213'], consequent=['5000128889889'], confidence=0.5, lift=556.67),
#  Row(antecedent=['5010228013213'], consequent=['5000205039862'], confidence=0.5, lift=1670.0),
#  Row(antecedent=['5010228013213'], consequent=['8712566328352'], confidence=0.5, lift=835.0),
#  Row(antecedent=['5010228013213'], consequent=['5000205034546'], confidence=0.5, lift=1002.0),
#  Row(antecedent=['5000116111473', '5000116102464', '5000116112050'], consequent=['5000116105007'], confidence=0.8, lift=1603.2),
#  Row(antecedent=['5000116111473', '5000116102464', '5000116112050'], consequent=['5010238013616'], confidence=0.6, lift=1503.0),
#  Row(antecedent=['5000116111473', '5000116102464', '5000116112050'], consequent=['5000116111800'], confidence=1.0, lift=910.91),
#  Row(antecedent=['5000128738248'], consequent=['0000000000145'], confidence=0.1875, lift=2.65),
#  Row(antecedent=['5000112624229'], consequent=['5000128785617'], confidence=0.3, lift=5.73),
#  Row(antecedent=['5000128797351'], consequent=['0000000000145'], confidence=0.4, lift=5.66),
#  Row(antecedent=['5010044000039'], consequent=['8004260452816'], confidence=0.0682, lift=15.89),
#  Row(antecedent=['5010044000039'], consequent=['9770307268922'], confidence=0.0682, lift=2.96),
#  Row(antecedent=['5010044000039'], consequent=['5000128785617'], confidence=0.0909, lift=1.74),
#  Row(antecedent=['5010044000039'], consequent=['5000128104524'], confidence=0.1818, lift=6.48),
#  Row(antecedent=['5010044000039'], consequent=['0000000000145'], confidence=0.1364, lift=1.93),
#  Row(antecedent=['7622210154125'], consequent=['5000128785617'], confidence=0.1389, lift=2.65),
#  Row(antecedent=['7622210154125'], consequent=['7622300845759'], confidence=0.1667, lift=26.94),
#  Row(antecedent=['5449000124999'], consequent=['5000128785617'], confidence=0.1538, lift=2.94),
#  Row(antecedent=['5449000124999'], consequent=['5000237121252'], confidence=0.1154, lift=36.13),
#  Row(antecedent=['9772044733053'], consequent=['5000128104494'], confidence=0.0625, lift=3.04),
#  Row(antecedent=['9772044733053'], consequent=['2083803000000'], confidence=0.0469, lift=1.6),
#  Row(antecedent=['9772044733053'], consequent=['9770307268922'], confidence=0.0781, lift=3.39),
#  Row(antecedent=['9772044733053'], consequent=['9770957623928'], confidence=0.0625, lift=9.63),
#  Row(antecedent=['9772044733053'], consequent=['0000000007535'], confidence=0.0469, lift=2.21),
#  Row(antecedent=['9772044733053'], consequent=['9772059005046'], confidence=0.0469, lift=10.44),
#  Row(antecedent=['9772044733053'], consequent=['7622300845759'], confidence=0.0469, lift=7.58),
#  Row(antecedent=['5000431026995'], consequent=['5000128785617'], confidence=0.0588, lift=1.12),
#  Row(antecedent=['5000431026995'], consequent=['0000000000145'], confidence=0.0784, lift=1.11),
#  Row(antecedent=['5017600020074'], consequent=['5000159484527'], confidence=0.0566, lift=13.83),
#  Row(antecedent=['5017600020074'], consequent=['5010115926404'], confidence=0.0566, lift=9.15),
#  Row(antecedent=['5017600020074'], consequent=['6191514300312'], confidence=0.0943, lift=3.96),
#  Row(antecedent=['5017600020074'], consequent=['5010044005126'], confidence=0.0566, lift=7.77),
#  Row(antecedent=['5017600020074'], consequent=['5000128779814'], confidence=0.0566, lift=6.83),
#  Row(antecedent=['5017600020074'], consequent=['0000000007535'], confidence=0.0566, lift=2.66),
#  Row(antecedent=['5017600020074'], consequent=['0000000000145'], confidence=0.0943, lift=1.34),
#  Row(antecedent=['5000128104463'], consequent=['5000128412810'], confidence=0.0508, lift=9.26),
#  Row(antecedent=['5000128104463'], consequent=['5000128104456'], confidence=0.0678, lift=15.44),
#  Row(antecedent=['5000128104463'], consequent=['5000128104494'], confidence=0.1186, lift=5.77),
#  Row(antecedent=['5000128104463'], consequent=['9770307268922'], confidence=0.0508, lift=2.21),
#  Row(antecedent=['5000128104463'], consequent=['6191514300312'], confidence=0.0508, lift=2.13),
#  Row(antecedent=['5000128104463'], consequent=['0000000000644'], confidence=0.0508, lift=2.43),
#  Row(antecedent=['5000128104463'], consequent=['5000128785617'], confidence=0.1356, lift=2.59),
#  Row(antecedent=['5000128104463'], consequent=['5000128756617'], confidence=0.0508, lift=7.28),
#  Row(antecedent=['5000128104463'], consequent=['0000000007535'], confidence=0.1017, lift=4.78),
#  Row(antecedent=['5000128104463'], consequent=['5000128861069'], confidence=0.0847, lift=8.66),
#  Row(antecedent=['5000128104463'], consequent=['0000000000145'], confidence=0.1186, lift=1.68),
#  Row(antecedent=['5000128966269'], consequent=['0000000000644'], confidence=0.1579, lift=7.53),
#  Row(antecedent=['5410316671118'], consequent=['0000000000644'], confidence=0.2143, lift=10.22),
#  Row(antecedent=['0000054491397'], consequent=['5000128711449'], confidence=0.12, lift=28.63),
#  Row(antecedent=['5000128766586'], consequent=['5000128766708'], confidence=0.1212, lift=18.98),
#  Row(antecedent=['5000128766586'], consequent=['5000128785617'], confidence=0.1212, lift=2.31),
#  Row(antecedent=['5000128766586'], consequent=['5000128585972'], confidence=0.1515, lift=116.78),
#  Row(antecedent=['5010044000039', '0000000000145'], consequent=['5000128104524'], confidence=0.8333, lift=29.72),
#  Row(antecedent=['5000328541082'], consequent=['5000328540290'], confidence=0.3333, lift=208.75),
#  Row(antecedent=['5449000214522'], consequent=['0000000000145'], confidence=0.25, lift=3.54),
#  Row(antecedent=['5000128998031', '5000128922296'], consequent=['5000128861069'], confidence=0.8, lift=81.8),
#  Row(antecedent=['5000128667302'], consequent=['5000128271165'], confidence=0.4286, lift=42.94),
#  Row(antecedent=['5000128667302'], consequent=['0000000000145'], confidence=0.4286, lift=6.07),
#  Row(antecedent=['7622210286918'], consequent=['0000000000644'], confidence=0.093, lift=4.44),
#  Row(antecedent=['7622210286918'], consequent=['7622210286956'], confidence=0.1628, lift=21.46),
#  Row(antecedent=['7622210286918'], consequent=['5000128785617'], confidence=0.093, lift=1.78),
#  Row(antecedent=['7622210286918'], consequent=['0000000000145'], confidence=0.093, lift=1.32),
#  Row(antecedent=['3664346304863'], consequent=['5000128785617'], confidence=0.1154, lift=2.2),
#  Row(antecedent=['3664346304863'], consequent=['0000000000145'], confidence=0.2308, lift=3.27),
#  Row(antecedent=['5000128582575'], consequent=['5000128816151'], confidence=0.3333, lift=278.33),
#  Row(antecedent=['5000128675345'], consequent=['0000000000145'], confidence=0.1379, lift=1.95),
#  Row(antecedent=['6100000000193', '2083803000000'], consequent=['2083807000006'], confidence=0.15, lift=60.12),
#  Row(antecedent=['6100000000193', '2083803000000'], consequent=['2083804000009'], confidence=0.15, lift=31.31),
#  Row(antecedent=['6100000000193', '2083803000000'], consequent=['2083801000002'], confidence=0.15, lift=18.11),
#  Row(antecedent=['9770307268922'], consequent=['5000128766968'], confidence=0.013, lift=4.2),
#  Row(antecedent=['9770307268922'], consequent=['9770958575820'], confidence=0.0173, lift=24.79),
#  Row(antecedent=['9770307268922'], consequent=['5000328347790'], confidence=0.013, lift=3.17),
#  Row(antecedent=['9770307268922'], consequent=['5000143923117'], confidence=0.013, lift=3.61),
#  Row(antecedent=['9770307268922'], consequent=['9770307017124'], confidence=0.026, lift=5.31),
#  Row(antecedent=['9770307268922'], consequent=['5000128104494'], confidence=0.026, lift=1.26),
#  Row(antecedent=['9770307268922'], consequent=['5000128979917'], confidence=0.013, lift=3.1),
#  Row(antecedent=['9770307268922'], consequent=['0000000004729'], confidence=0.013, lift=2.83),
#  Row(antecedent=['9770307268922'], consequent=['5010044000121'], confidence=0.013, lift=1.46),
#  Row(antecedent=['9770307268922'], consequent=['2083804000009'], confidence=0.0216, lift=4.52),
#  Row(antecedent=['9770307268922'], consequent=['9770957623928'], confidence=0.0779, lift=12.01),
#  Row(antecedent=['9770307268922'], consequent=['9770956806926'], confidence=0.013, lift=4.34),
#  Row(antecedent=['9770307268922'], consequent=['9770962166465'], confidence=0.0216, lift=24.1),
#  Row(antecedent=['9770307268922'], consequent=['9772044733053'], confidence=0.0216, lift=3.39),
#  Row(antecedent=['9770307268922'], consequent=['5000128918305'], confidence=0.0173, lift=1.87),
#  Row(antecedent=['9770307268922'], consequent=['5000128104517'], confidence=0.013, lift=1.16),
#  Row(antecedent=['9770307268922'], consequent=['5010044000039'], confidence=0.013, lift=2.96),
#  Row(antecedent=['9770307268922'], consequent=['5010044000275'], confidence=0.013, lift=2.6),
#  Row(antecedent=['9770307268922'], consequent=['5000128072915'], confidence=0.013, lift=2.21),
#  Row(antecedent=['9770307268922'], consequent=['2083801000002'], confidence=0.013, lift=1.57),
#  Row(antecedent=['9770307268922'], consequent=['5000128104463'], confidence=0.013, lift=2.21),
#  Row(antecedent=['9770307268922'], consequent=['9771358588120'], confidence=0.0216, lift=19.72),
#  Row(antecedent=['9770307268922'], consequent=['9771056348958'], confidence=0.013, lift=18.59),
#  Row(antecedent=['9770307268922'], consequent=['2083803000000'], confidence=0.0606, lift=2.07),
#  Row(antecedent=['9770307268922'], consequent=['6191514300312'], confidence=0.026, lift=1.09),
#  Row(antecedent=['9770307268922'], consequent=['5000128785617'], confidence=0.026, lift=0.5),
#  Row(antecedent=['9770307268922'], consequent=['5000128104524'], confidence=0.013, lift=0.46),
#  Row(antecedent=['9770307268922'], consequent=['0000000000145'], confidence=0.0476, lift=0.67),
#  Row(antecedent=['9770307268922'], consequent=['5000128662468'], confidence=0.013, lift=7.65),
#  Row(antecedent=['9770307268922'], consequent=['9770043722443'], confidence=0.013, lift=16.27),
#  Row(antecedent=['9770307268922'], consequent=['5000128597487'], confidence=0.013, lift=5.0),
#  Row(antecedent=['9770307268922'], consequent=['5000128959759'], confidence=0.013, lift=3.72),
#  Row(antecedent=['9770307268922'], consequent=['0000000000644'], confidence=0.013, lift=0.62),
#  Row(antecedent=['9770307268922'], consequent=['9772059005046'], confidence=0.013, lift=2.89),
#  Row(antecedent=['9770307268922'], consequent=['2116570001816'], confidence=0.013, lift=13.01),
#  Row(antecedent=['9770307268922'], consequent=['9770956805424'], confidence=0.0606, lift=6.53),
#  Row(antecedent=['9770307268922'], consequent=['5000128753708'], confidence=0.013, lift=16.27),
#  Row(antecedent=['9770307268922'], consequent=['5000128279840'], confidence=0.013, lift=1.78),
#  Row(antecedent=['9770307268922'], consequent=['9770307757129'], confidence=0.0476, lift=2.74),
#  Row(antecedent=['9770307268922'], consequent=['5000128372190'], confidence=0.0346, lift=3.94),
#  Row(antecedent=['9770307268922'], consequent=['9772045492829'], confidence=0.0173, lift=4.13),
#  Row(antecedent=['5000128989367'], consequent=['5000128744898'], confidence=0.0962, lift=22.41),
#  Row(antecedent=['5000128989367'], consequent=['5000128879606'], confidence=0.0769, lift=8.2),
#  Row(antecedent=['5000128989367'], consequent=['5000128998031'], confidence=0.0962, lift=16.61),
#  Row(antecedent=['5000128989367'], consequent=['0000000004053'], confidence=0.0577, lift=10.91),
#  Row(antecedent=['5000128989367'], consequent=['5000128104494'], confidence=0.0577, lift=2.81),
#  Row(antecedent=['5000128989367'], consequent=['5000128271165'], confidence=0.0769, lift=7.71),
#  Row(antecedent=['5000128989367'], consequent=['5000128267540'], confidence=0.0577, lift=9.18),
#  Row(antecedent=['5000128989367'], consequent=['5000128785617'], confidence=0.0769, lift=1.47),
#  Row(antecedent=['5000128989367'], consequent=['5000128918305'], confidence=0.0577, lift=6.22),
#  Row(antecedent=['5000128989367'], consequent=['5000128104524'], confidence=0.0769, lift=2.74),
#  Row(antecedent=['5000128989367'], consequent=['5000128756617'], confidence=0.0577, lift=8.26),
#  Row(antecedent=['5000128989367'], consequent=['5000128861069'], confidence=0.0577, lift=5.9),
#  Row(antecedent=['5000128989367'], consequent=['0000000000145'], confidence=0.1538, lift=2.18),
#  Row(antecedent=['5000128989367'], consequent=['5000128932912'], confidence=0.0577, lift=13.14),
#  Row(antecedent=['5000128989367'], consequent=['5000128624763'], confidence=0.0577, lift=26.28),
#  Row(antecedent=['5000128989367'], consequent=['5000128997195'], confidence=0.0577, lift=64.23),
#  Row(antecedent=['5000128989367'], consequent=['5000128475389'], confidence=0.0577, lift=26.28),
#  Row(antecedent=['5000128989367'], consequent=['5000128317696'], confidence=0.0577, lift=14.82),
#  Row(antecedent=['5000128989367'], consequent=['0000000004048'], confidence=0.0577, lift=44.47),
#  Row(antecedent=['5000128989367'], consequent=['5000128947688'], confidence=0.0577, lift=32.12),
#  Row(antecedent=['5000128989367'], consequent=['5000128989640'], confidence=0.0577, lift=30.43),
#  Row(antecedent=['5000128989367'], consequent=['5000128946834'], confidence=0.0577, lift=34.0),
#  Row(antecedent=['5000128989367'], consequent=['0000000004562'], confidence=0.0769, lift=22.02),
#  Row(antecedent=['5000128989367'], consequent=['5000128074339'], confidence=0.0577, lift=26.28),
#  Row(antecedent=['5000128989367'], consequent=['0000050129119'], confidence=0.0577, lift=12.57),
#  Row(antecedent=['5000116105007', '5000116111473', '5000116112050'], consequent=['5000116102464'], confidence=1.0, lift=835.0),
#  Row(antecedent=['5000116105007', '5000116111473', '5000116112050'], consequent=['5000116111800'], confidence=1.0, lift=910.91),
#  Row(antecedent=['5000128946834'], consequent=['5000128989367'], confidence=0.1765, lift=34.0),
#  Row(antecedent=['5000128946834'], consequent=['5000128779814'], confidence=0.1765, lift=21.3),
#  Row(antecedent=['5000128946834'], consequent=['0000000000145'], confidence=0.2941, lift=4.16),
#  Row(antecedent=['5000128723244'], consequent=['5000128922296'], confidence=0.3, lift=35.36),
#  Row(antecedent=['5000128860550'], consequent=['5000128271165'], confidence=0.3, lift=30.06),
#  Row(antecedent=['5000128915618', '5000128879606'], consequent=['5000128271165'], confidence=0.6, lift=60.12),
#  Row(antecedent=['5022313331607'], consequent=['5000128591614'], confidence=0.4286, lift=102.24),
#  Row(antecedent=['5000128104524', '2083803000000'], consequent=['2083801000002'], confidence=0.4286, lift=51.74),
#  Row(antecedent=['0000000000145'], consequent=['5000128711449'], confidence=0.0042, lift=1.01),
#  Row(antecedent=['0000000000145'], consequent=['5000168187167'], confidence=0.0042, lift=1.46),
#  Row(antecedent=['0000000000145'], consequent=['5010292944536'], confidence=0.0042, lift=7.08),
#  Row(antecedent=['0000000000145'], consequent=['3256540001565'], confidence=0.0042, lift=4.25),
#  Row(antecedent=['0000000000145'], consequent=['5000128766968'], confidence=0.0099, lift=3.2),
#  Row(antecedent=['0000000000145'], consequent=['0000050173686'], confidence=0.0056, lift=1.45),
#  Row(antecedent=['0000000000145'], consequent=['0000050129003'], confidence=0.0056, lift=3.33),
#  Row(antecedent=['0000000000145'], consequent=['7613035570917'], confidence=0.0042, lift=5.31),
#  Row(antecedent=['0000000000145'], consequent=['5000128738606'], confidence=0.0042, lift=3.54),
#  ...]

# %%
model.transform(df).select('ResponseRgBasketId','ItemList','prediction').show()
# Out:
# +--------------------+--------------------+--------------------+
# |  ResponseRgBasketId|            ItemList|          prediction|
# +--------------------+--------------------+--------------------+
# |cf31c58d05ca41bda...|[5000128725477, 5...|[5000128104494, 0...|
# |1d385ce056e1463a8...|[5010891011868, 8...|                  []|
# |b9083214cf6c4593b...|[5000128797436, 5...|[0000000000145, 5...|
# |7da158b1c1d14fdf8...|[4062300011847, 5...|     [5000128785617]|
# |ce2c0ef55f4c47d1b...|[6191514300312, 5...|[0000000000145, 5...|
# |23af5a43bb3043b3a...|[9770307268922, 5...|[5000128766968, 9...|
# |e9e24506d4c64b5ba...|     [7622210286314]|     [5000159457873]|
# |43a4bfda05d44538b...|[5000128677127, 7...|                  []|
# |6ce95a109c024ce9a...|     [0000050457243]|[5000128785617, 0...|
# |cebc44a6e43d4c9f9...|     [5000431027169]|                  []|
# |e6aa26eb00c947389...|     [5000128104517]|[5010044000305, 5...|
# |3f64f54e8dcc42758...|[5037435002335, 7...|[0000000000145, 5...|
# |3b898aa2b03f4afb8...|     [5000128758499]|                  []|
# |c7db62c95d94417ca...|[0000050226856, 5...|[5000128989367, 5...|
# |a3729afebf6240ffb...|[5000128413244, 5...|[5000128983167, 0...|
# |c68b4fa0753942278...|     [5000128789936]|                  []|
# |5986fec044ee4f5c8...|[5000143911213, 5...|                  []|
# |4f8b41f772bf45119...|[5000128808477, 9...|[5000128766968, 9...|
# |fd626634d3b349a49...|[5449000004840, 3...|                  []|
# |63e7e06bcc7147a58...|[7622210106988, 5...|     [0000000000145]|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Create single rule and double rule dataframe

# %%
from pyspark.sql.functions import col, size
single_rule_df = rules.where(size(col('antecedent')) == 1).where(size(col('consequent')) == 1) ## extracting only single rules
double_rule_df = rules.where(size(col('antecedent')) == 2).where(size(col('consequent')) == 1) ## extracting only double rules

# %%
double_rule_df.show()
# Out:
# +--------------------+---------------+----------+-------+
# |          antecedent|     consequent|confidence|   lift|
# +--------------------+---------------+----------+-------+
# |[5000128663250, 0...|[5000128661911]|      0.75| 289.04|
# |[2083801000002, 2...|[6100000000193]|    0.0833|   7.32|
# |[2083801000002, 2...|[9770307268922]|    0.0833|   3.61|
# |[2083801000002, 2...|[5000128104524]|    0.0833|   2.97|
# |[5000205034546, 8...|[5000205039862]|       1.0| 3340.0|
# |[5000205034546, 8...|[5010228013213]|       1.0| 1670.0|
# |[5000205034546, 8...|[5000128889889]|       1.0|1113.33|
# |[9770307017124, 2...|[9770307757129]|       0.5|  28.79|
# |[0000050128747, 5...|[5000128279796]|    0.4286| 429.43|
# |[0000050128747, 5...|[5000128918305]|    0.4286|  46.18|
# |[5000128879606, 5...|[5000128915618]|    0.4286|  81.02|
# |[5000128104517, 5...|[9770307757129]|    0.1304|   7.51|
# |[5000128104517, 5...|[5000128861069]|    0.1304|  13.34|
# |[9771056348958, 9...|[9770307268922]|       1.0|  43.38|
# |[2083801000002, 6...|[2083803000000]|      0.75|  25.56|
# |[5000128317696, 0...|[5000128712156]|       0.6| 158.21|
# |[2083807000006, 2...|[6100000000193]|       0.3|  26.37|
# |[2083807000006, 2...|[2083804000009]|       0.4|   83.5|
# |[5000128712156, 0...|[5000128317696]|      0.75| 192.69|
# |[9770307268922, 0...|[9770957623928]|    0.2727|  42.04|
# +--------------------+---------------+----------+-------+
# only showing top 20 rows

# %%
single_rule_df.count()
#single_rule_df.withColumn("antecedent", single_rule_df.antecedent.cast("StringType"))
#single_rule_df.write.csv("file.csv")
# Out:
# 3386

# %% [markdown]
# Export dataframes

# %%
def toCSVLine(data):

  return ','.join(str(d) for d in data)

single_lines = single_rule_df.rdd.map(toCSVLine)
double_lines = double_rule_df.rdd.map(toCSVLine)
#lines = single_rule_df.rdd.map(lambda x: ','.join(str(d) for d in x))

single_lines.coalesce(1).saveAsTextFile('single_rule_file')
double_lines.coalesce(1).saveAsTextFile('double_rule_file')
